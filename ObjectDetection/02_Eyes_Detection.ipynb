# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Open Image

# %%
image = cv2.imread('Images/eye_face.jpg')

# %% [markdown]
# ### Show Image

# %%
plt.imshow(image)

# %% [markdown]
# ### Fix Image

# %%
fix_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Show Image

# %%
plt.imshow(fix_img)

# %% [markdown]
# ### Create Classifier

# %%
eye_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')

# %% [markdown]
# ### It's a Kind of Magic

# %%
def detect_eyes(fix_img):
    eye_rects = eye_classifier.detectMultiScale(fix_img, 1.3, 5)
    
    for (x,y,w,h) in eye_rects:
        cv2.rectangle(fix_img, (x,y), (x+w, y+h), (255,0,0), 4)
    
    return fix_img

# %% [markdown]
# ### Show Results

# %%
result = detect_eyes(fix_img)
plt.figure(figsize = (20,15))
plt.imshow(fix_img)
